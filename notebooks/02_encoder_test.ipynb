# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))


import numpy as np

# %%
Z = np.load("../models/embeddings/wine_embeddings.npy")

# %%
from src.evaluation.retrieval import top_k

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/wines_clean.csv")

# %%
n = np.random.randint(0,df.shape[0])

df.iloc[np.concatenate((top_k(n,2),[n]))]
# Out:
#          id                                               name  precio  \
# 6921   6529  Clos quebrada de macul domus aurea cabernet sa...   54000
# 1381   4400  Santa rita casa real reserva especial cabernet...   48482
# 1022  10063        Ventisquero enclave cabernet sauvignon 2015   58990
#
#       puntaje   tipo                cepa mezcla  cosecha  valle  \
# 6921       93  Tinto  Cabernet Sauvignon     CS   2009.0  Maipo
# 1381       94  Tinto  Cabernet Sauvignon     CS   2007.0  Maipo
# 1022       93  Tinto  Cabernet Sauvignon     CS   2015.0  Maipo
#
#                                               nota_cata  ...  m_carnescaza  \
# 6921  Nariz a chocolate, ciruelas, frutillas macerad...  ...             1
# 1381  Rojo cereza brillante. Nariz especiada, trufa,...  ...             1
# 1022  Rojo cereza teja. Nariz a frutos rojos, ciruel...  ...             1
#
#       m_pescados  m_comidachilena  m_cerdo  m_cordero  m_pasta  m_crustaceos  \
# 6921           0                0        0          0        0             0
# 1381           0                0        0          0        0             0
# 1022           0                0        0          0        0             0
#
#       m_mariscos  m_comidaoriental  m_postres
# 6921           0                 0          0
# 1381           0                 0          0
# 1022           0                 0          0
#
# [3 rows x 28 columns]
