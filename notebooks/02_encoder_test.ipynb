# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))


import numpy as np

# %%
Z = np.load("../models/embeddings/wine_embeddings.npy")

# %%
from src.evaluation.retrieval import top_k

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/wines_clean.csv")

# %%
n = np.random.randint(0,df.shape[0])

df.iloc[np.concatenate((top_k(n,5),[n]))]["name"]
# Out:
# 7804                          Alcance vigno carignan 2015
# 6859                Garcia schwaderer vigno carignan 2014
# 5134    Requingua toro de piedra gran reseva carignan ...
# 7171                            Dagaz vigno carignan 2020
# 6173                         Gillmore vigno carignan 2013
# 3331               Luis felipe edwards cien carignan 2012
# Name: name, dtype: object
