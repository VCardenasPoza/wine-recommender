# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

import matplotlib.pyplot as plt

import numpy as np

# %%
Z2 = np.load("../models/embeddings/2d_embedding.npy")

# %%
plt.scatter(Z2[:,0],Z2[:,1])

# %%
import plotly.express as px

import pandas as pd

# %%
df = pd.read_csv("../data/processed/wines_clean.csv")

# %%
df["dim 1"] = Z2[:,0]
df["dim 2"] = Z2[:,1]

# %%
fig = px.scatter(df,x="dim 1",y="dim 2",color="cepa",hover_data="name")
fig.write_image("../reports/umap_wines.png")
fig.write_html("../reports/umap_wines.html")

# %%
fig.show()
